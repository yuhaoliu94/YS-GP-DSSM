# %%
import os
import pickle
os.getcwd()
os.chdir("../")

import numpy as np
from matplotlib import pyplot as plt

# %%
from src.gpdssm.models import StandardSingleModel, YuleSimonSingleModel
from src.gpdssm.models_ys import ModelLayer, YuleSimonModel
from src.gpdssm.utils import normalize_weights

# %%
def mean_average(states, N=100):
    return np.convolve(states, np.ones(N)/N, mode='valid')

# %%
cwd = os.getcwd()
model_path = os.path.join(cwd, "models", "train_2.pickle")
with open(model_path, 'rb') as f:
    model_list = pickle.load(f)

# %%
cwd = os.getcwd()
Z_path = os.path.join(cwd, "folds", "test_fold_21_Z.txt")
with open(Z_path, 'rb') as f:
    Z_act = pickle.load(f)

# %%
C = 3

# %%
ys_single_model_list = []


for i in range(C):
    param = {"data_name": model_list[i].data_name,
             "data_fold": model_list[i].data_fold,
             "dim_hidden": model_list[i].dim_hidden,
             "num_rff": model_list[i].J,
             "num_particle": 1000, #model_list[i].M,
             "display_step": model_list[i].display_step,
             "warm_start": model_list[i].warm_start,
             "learning_rate": model_list[i].learning_rate,
             "num_train_cycle": model_list[i].num_train_cycle,
            }
    
    ys_single_model = YuleSimonSingleModel(C, **param)
    ys_single_model.initialize_structure_from_functions(model_list[i].functions[:-1], model_list[-1].functions[-1])
    ys_single_model_list.append(ys_single_model)

# %%
a0 = np.array([5] * C)
b0 = np.array([1] * C)
ys_model = YuleSimonModel(data_name="test", data_fold=21, model_list=ys_single_model_list,
                         num_rff=50, num_particle=1000, a0=a0, b0=b0,
                         display_step=100, warm_start=0, learning_rate=0.001, num_train_cycle=1)

# %%
ys_model.learn()
# Out:
# >>> train cycle 1
# >>> cycle=1, t=1, mse=9.072, mnll=14591.4759, time=0.0 minutes
# >>> cycle=1, t=100, mse=9.5516, mnll=22075.359, time=0.05 minutes
# >>> cycle=1, t=200, mse=9.5564, mnll=24082.6716, time=0.09 minutes
# >>> cycle=1, t=300, mse=8.6341, mnll=23069.7263, time=0.14 minutes
# >>> cycle=1, t=400, mse=7.9486, mnll=22477.586, time=0.18 minutes
# >>> cycle=1, t=500, mse=7.7334, mnll=22610.3758, time=0.22 minutes
# >>> cycle=1, t=600, mse=7.6856, mnll=21859.9338, time=0.27 minutes
# >>> cycle=1, t=700, mse=7.4973, mnll=22270.6625, time=0.32 minutes
# >>> cycle=1, t=800, mse=7.4865, mnll=22121.6235, time=0.36 minutes
# >>> cycle=1, t=900, mse=7.5039, mnll=22476.0244, time=0.41 minutes
# >>> cycle=1, t=1000, mse=7.5648, mnll=22988.5817, time=0.46 minutes
# >>> cycle=1, t=1100, mse=8.5221, mnll=22517.699, time=0.51 minutes
# >>> cycle=1, t=1200, mse=9.0026, mnll=22078.2698, time=0.56 minutes
# >>> cycle=1, t=1300, mse=9.3391, mnll=21599.2144, time=0.61 minutes
# >>> cycle=1, t=1400, mse=9.9147, mnll=21310.8568, time=0.66 minutes
# >>> cycle=1, t=1500, mse=10.4583, mnll=21031.7447, time=0.71 minutes
# >>> cycle=1, t=1600, mse=10.6842, mnll=20748.0279, time=0.77 minutes
# >>> cycle=1, t=1700, mse=10.9802, mnll=20523.1058, time=0.82 minutes
# >>> cycle=1, t=1800, mse=11.4688, mnll=20456.1294, time=0.88 minutes
# >>> cycle=1, t=1900, mse=11.6301, mnll=20346.6223, time=0.93 minutes
# >>> cycle=1, t=2000, mse=11.9021, mnll=20287.7305, time=0.99 minutes
# >>> cycle=1, t=2100, mse=12.084, mnll=20245.116, time=1.05 minutes
# >>> cycle=1, t=2200, mse=12.0984, mnll=20196.3103, time=1.12 minutes
# >>> cycle=1, t=2300, mse=12.2385, mnll=20205.1467, time=1.18 minutes
# >>> cycle=1, t=2400, mse=12.3059, mnll=20195.0194, time=1.25 minutes
# >>> cycle=1, t=2500, mse=12.4687, mnll=20261.5211, time=1.32 minutes
# >>> cycle=1, t=2600, mse=12.4637, mnll=20203.9995, time=1.39 minutes
# >>> cycle=1, t=2700, mse=12.5193, mnll=20273.2051, time=1.46 minutes
# >>> cycle=1, t=2800, mse=12.5388, mnll=20195.7695, time=1.53 minutes
# >>> cycle=1, t=2900, mse=12.6648, mnll=20249.2887, time=1.6 minutes
# >>> cycle=1, t=3000, mse=12.7557, mnll=20237.8214, time=1.68 minutes
# >>> cycle=1, t=3100, mse=12.6617, mnll=20213.864, time=1.76 minutes
# >>> cycle=1, t=3200, mse=12.4306, mnll=20245.8373, time=1.84 minutes
# >>> cycle=1, t=3300, mse=12.2331, mnll=20113.8968, time=1.92 minutes
# >>> cycle=1, t=3400, mse=12.029, mnll=20145.4736, time=2.01 minutes
# >>> cycle=1, t=3500, mse=11.8428, mnll=20075.7679, time=2.09 minutes
# >>> cycle=1, t=3600, mse=11.698, mnll=20100.4097, time=2.18 minutes
# >>> cycle=1, t=3700, mse=11.5234, mnll=20129.9257, time=2.27 minutes
# >>> cycle=1, t=3800, mse=11.3561, mnll=20108.927, time=2.36 minutes
# >>> cycle=1, t=3900, mse=11.2, mnll=20052.5981, time=2.46 minutes
# >>> cycle=1, t=4000, mse=11.0372, mnll=20026.2944, time=2.55 minutes
# >>> cycle=1, t=4100, mse=10.9009, mnll=19990.3272, time=2.64 minutes
# >>> cycle=1, t=4200, mse=10.7662, mnll=19980.4571, time=2.74 minutes
# >>> cycle=1, t=4300, mse=10.6412, mnll=19979.6027, time=2.83 minutes
# >>> cycle=1, t=4400, mse=10.5099, mnll=19906.2507, time=2.93 minutes
# >>> cycle=1, t=4500, mse=10.3902, mnll=19869.789, time=3.03 minutes
# >>> cycle=1, t=4600, mse=10.2811, mnll=19816.8768, time=3.13 minutes
# >>> cycle=1, t=4700, mse=10.169, mnll=19779.9882, time=3.23 minutes
# >>> cycle=1, t=4800, mse=10.0825, mnll=19779.1703, time=3.33 minutes
# >>> cycle=1, t=4900, mse=9.997, mnll=19738.8992, time=3.43 minutes
# >>> cycle=1, t=5000, mse=9.9008, mnll=19749.3149, time=3.54 minutes
# >>> cycle=1, t=5100, mse=10.0231, mnll=19833.6103, time=3.64 minutes
# >>> cycle=1, t=5200, mse=10.1704, mnll=19930.3002, time=3.75 minutes
# >>> cycle=1, t=5300, mse=10.3367, mnll=19944.7963, time=3.86 minutes
# >>> cycle=1, t=5400, mse=10.4891, mnll=20017.9936, time=3.96 minutes
# >>> cycle=1, t=5500, mse=10.6386, mnll=20067.5713, time=4.07 minutes
# >>> cycle=1, t=5600, mse=10.7856, mnll=20129.65, time=4.18 minutes
# >>> cycle=1, t=5700, mse=10.9264, mnll=20237.3094, time=4.29 minutes
# >>> cycle=1, t=5800, mse=11.0603, mnll=20284.5456, time=4.4 minutes
# >>> cycle=1, t=5900, mse=11.148, mnll=20296.2829, time=4.52 minutes
# >>> cycle=1, t=6000, mse=11.215, mnll=20388.3448, time=4.63 minutes
# >>> cycle=1, t=6100, mse=11.164, mnll=20398.4368, time=4.75 minutes
# >>> cycle=1, t=6200, mse=11.0916, mnll=20317.6377, time=4.87 minutes
# >>> cycle=1, t=6300, mse=11.0046, mnll=20311.7853, time=4.99 minutes
# >>> cycle=1, t=6400, mse=10.9268, mnll=20269.6281, time=5.11 minutes
# >>> cycle=1, t=6500, mse=10.8693, mnll=20173.3096, time=5.23 minutes
# >>> cycle=1, t=6600, mse=10.792, mnll=20158.6429, time=5.36 minutes
# >>> cycle=1, t=6700, mse=10.7176, mnll=20122.079, time=5.48 minutes
# >>> cycle=1, t=6800, mse=10.6436, mnll=20132.3533, time=5.61 minutes
# >>> cycle=1, t=6900, mse=10.5761, mnll=20115.4093, time=5.73 minutes
# >>> cycle=1, t=7000, mse=10.508, mnll=20128.024, time=5.86 minutes
# >>> cycle=1, t=7100, mse=10.4373, mnll=20117.493, time=5.99 minutes
# >>> cycle=1, t=7200, mse=10.3592, mnll=20109.8208, time=6.12 minutes
# >>> cycle=1, t=7300, mse=10.2903, mnll=20060.2529, time=6.25 minutes
# >>> cycle=1, t=7400, mse=10.2376, mnll=20030.1255, time=6.39 minutes
# >>> cycle=1, t=7500, mse=10.1874, mnll=20008.2613, time=6.52 minutes
# >>> cycle=1, t=7600, mse=10.1349, mnll=19982.127, time=6.66 minutes
# >>> cycle=1, t=7700, mse=10.0685, mnll=19964.7489, time=6.79 minutes
# >>> cycle=1, t=7800, mse=10.0181, mnll=19917.1971, time=6.93 minutes
# >>> cycle=1, t=7900, mse=9.9561, mnll=19884.5807, time=7.07 minutes
# >>> cycle=1, t=8000, mse=9.8955, mnll=19849.5197, time=7.21 minutes
# >>> cycle=1, t=8100, mse=9.8439, mnll=19829.4461, time=7.35 minutes
# >>> cycle=1, t=8200, mse=9.8131, mnll=19789.641, time=7.49 minutes
# >>> cycle=1, t=8300, mse=9.7609, mnll=19740.0065, time=7.63 minutes
# >>> cycle=1, t=8400, mse=9.7224, mnll=19704.8642, time=7.77 minutes
# >>> cycle=1, t=8500, mse=9.6753, mnll=19692.4366, time=7.92 minutes
# >>> cycle=1, t=8600, mse=9.6254, mnll=19724.8884, time=8.07 minutes
# >>> cycle=1, t=8700, mse=9.5668, mnll=19734.2874, time=8.21 minutes
# >>> cycle=1, t=8800, mse=9.516, mnll=19707.2888, time=8.37 minutes
# >>> cycle=1, t=8900, mse=9.4734, mnll=19685.0892, time=8.52 minutes
# >>> cycle=1, t=9000, mse=9.424, mnll=19701.7915, time=8.67 minutes
# >>> cycle=1, t=9100, mse=9.4778, mnll=19755.0799, time=8.82 minutes
# >>> cycle=1, t=9200, mse=9.5454, mnll=19776.8737, time=8.97 minutes
# >>> cycle=1, t=9300, mse=9.634, mnll=19848.0968, time=9.12 minutes
# >>> cycle=1, t=9400, mse=9.7151, mnll=19957.4606, time=9.28 minutes
# >>> cycle=1, t=9500, mse=9.8566, mnll=19987.9333, time=9.43 minutes
# >>> cycle=1, t=9600, mse=10.0006, mnll=20173.6885, time=9.59 minutes
# >>> cycle=1, t=9700, mse=10.1092, mnll=20337.8681, time=9.74 minutes
# >>> cycle=1, t=9800, mse=10.2272, mnll=20495.4726, time=9.9 minutes
# >>> cycle=1, t=9900, mse=10.3069, mnll=20707.3284, time=10.06 minutes
# >>> cycle=1, t=10000, mse=10.3523, mnll=20890.2412, time=10.22 minutes

# %%
ys_layer = ys_model.ys_layer
stored_states = np.array(ys_layer.stored_states)
stored_states = np.array(stored_states[1:, :])
stored_particle_states = np.array(ys_layer.stored_particle_states)

# %%
stored_states_ma = np.array([mean_average(stored_states[:, i]) for i in range(C)]).T

# %%
plt.plot(stored_states[:, 0], label = "Predicted Prob of Class 0")
plt.savefig(os.path.join(cwd, "plots", "case2", "raw_est_prob_for_class_0.png"))

# %%
plt.plot(stored_states[:, 1], label = "Predicted Prob of Class 0")
plt.savefig(os.path.join(cwd, "plots", "case2", "raw_est_prob_for_class_1.png"))

# %%
plt.plot(stored_states[:, 2], label = "Predicted Prob of Class 0")
plt.savefig(os.path.join(cwd, "plots", "case2", "raw_est_prob_for_class_2.png"))

# %%
plt.plot(stored_states_ma[:, 0], label = "Predicted Prob of Class 0")
plt.plot(stored_states_ma[:, 1], label = "Predicted Prob of Class 1")
plt.plot(stored_states_ma[:, 2], label = "Predicted Prob of Class 2")
plt.legend()
plt.savefig(os.path.join(cwd, "plots", "case2", "ma_est_prob.png"))

# %%
argmax = np.argmax(stored_states_ma, axis=1)
plt.plot(argmax, label = "Predicted Class")
plt.plot(Z_act[99:], label = "Actual Class")
plt.legend()
plt.savefig(os.path.join(cwd, "plots", "case2", "arg_ma_est_prob.png"))

# %%
argmax = np.argmax(stored_states, axis=1)
plt.plot(mean_average(argmax), label = "Predicted Class")
plt.plot(Z_act[99:], label = "Actual Class")
plt.legend()
plt.savefig(os.path.join(cwd, "plots", "case2", "ma_arg_est_prob.png"))

# %%
pred = np.array(ys_model.ensemble_observation_layer.stored_states)

# %%
obs = ys_model.data.Y

# %%
for d in range(10):
    start = 4900
    end = start +100
    plt.plot(obs[start:end,d], label='obs')
    plt.plot(pred[start:end,d], label='pred')
    plt.legend()
    plt.show()
