# %%
import os
import pickle
os.getcwd()
os.chdir("../../")

import numpy as np
from matplotlib import pyplot as plt

# %%
from src.gpdssm.models import StandardSingleModel

# %%
def init_model(fold, cycle=1, learning_rate=0.001):
    model = StandardSingleModel(data_name="train", data_fold=fold, dim_hidden=[2], num_rff=50, num_particle=1000, 
                            display_step=2000, warm_start=0, learning_rate=learning_rate, num_train_cycle=cycle)
    return model

# def zero_round_learn(model_list):
#     for i in range(len(model_list)):
#         print("Class " + str(i) + " starts learning")
#         model_list[i].learn()

# def first_round_learn(model_list):
#     C = len(model_list)
#     new_model_list = [init_model(i, cycle_array[i-1]) for i in range(1, C+1)]
#     print("Class 0 starts learning")
#     new_model_list[0].initialize_structure_from_model(model_from_same_class = model_list[0])
#     new_model_list[0].learn()
    
#     for i in range(1, C):
#         print("Class " + str(i) + " starts learning")
#         new_model_list[i].initialize_structure_from_model(new_model_list[i-1], model_list[i])
#         new_model_list[i].learn()
        
#     return new_model_list

def first_round_learn(model_list):
    C = len(model_list)
    new_model_list = [init_model(20 + i) for i in range(1, C+1)]

    print("Class 0 starts learning")
    new_model_list[0].learn()
    
    for i in range(1, C):
        print("Class " + str(i) + " starts learning")
        new_model_list[i].initialize_structure_from_model(new_model_list[i-1])
        new_model_list[i].learn()
        
    return new_model_list
        
def next_round_learn(model_list, cycle_array, rate_array, stop, flag):
    C = len(model_list)
    new_model_list = [init_model(20 + i, cycle_array[i-1], rate_array[i-1]) for i in range(1, C+1)]
    
    # if not stop[0]:
    #     print("Class 0 starts learning")
    #     new_model_list[0].initialize_structure_from_model(model_list[flag], model_list[0])
    #     new_model_list[0].relearn()
    #     flag = 0
    # else:
    #     new_model_list[0] = model_list[0]
    
    for i in range(C):
        if not stop[i]:
            print("Class " + str(i) + " starts learning")
            if flag < i:
                new_model_list[i].initialize_structure_from_model(new_model_list[flag], model_list[i])
            else:
                new_model_list[i].initialize_structure_from_model(model_list[flag], model_list[i])
            new_model_list[i].relearn()
            flag = i
        else:
            new_model_list[i] = model_list[i]
        
            
    return new_model_list, flag

def get_mse_list(model_list):
    return [model_list[i].get_mse()[-1] for i in range(len(model_list))]

def check_stop(mse_list, model_list):
    new_mse_list = get_mse_list(model_list)
    ratio = np.array(new_mse_list) / np.array(mse_list)
    return new_mse_list, (ratio > 0.98) & (ratio < 1.02)

# %%
C = 3
cycle = [1, 5, 1]
rate = [0.001, 0.1, 0.01]
stop = [0, 0, 0]
flag = C - 1

# %%
model_list = [init_model(20 + i, cycle[i-1], rate[i-1]) for i in range(1, C+1)]

# zero_round_learn(model_list)
model_list = first_round_learn(model_list)

mse_list = get_mse_list(model_list)
# Out:
# Class 0 starts learning
# >>> train cycle 1
# >>> cycle=1, t=1, mse=2.2122, mnll=6.5302, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.3119, mnll=-23.0524, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.1628, mnll=-29.5809, time=0.61 minutes
# >>> cycle=1, t=6000, mse=0.1121, mnll=-33.3162, time=0.95 minutes
# >>> cycle=1, t=8000, mse=0.0862, mnll=-35.9103, time=1.27 minutes
# >>> cycle=1, t=10000, mse=0.0705, mnll=-37.8758, time=1.6 minutes
# Class 1 starts learning
# >>> train cycle 1
# >>> cycle=1, t=1, mse=10.7248, mnll=-375966.9086, time=0.0 minutes
# >>> cycle=1, t=2000, mse=1.9249, mnll=-206.387, time=0.31 minutes
# >>> cycle=1, t=4000, mse=1.7845, mnll=-121.9102, time=0.61 minutes
# >>> cycle=1, t=6000, mse=1.7398, mnll=-92.9072, time=0.98 minutes
# >>> cycle=1, t=8000, mse=1.7016, mnll=-79.792, time=1.31 minutes
# >>> cycle=1, t=10000, mse=1.679, mnll=-72.1651, time=1.65 minutes
# Class 2 starts learning
# >>> train cycle 1
# >>> cycle=1, t=1, mse=11.4709, mnll=-719379.6082, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.9592, mnll=-404.7998, time=0.33 minutes
# >>> cycle=1, t=4000, mse=0.8945, mnll=-224.7706, time=0.68 minutes
# >>> cycle=1, t=6000, mse=0.8602, mnll=-165.0036, time=1.0 minutes
# >>> cycle=1, t=8000, mse=0.8332, mnll=-135.2249, time=1.34 minutes
# >>> cycle=1, t=10000, mse=0.806, mnll=-117.4814, time=1.69 minutes

# %%
while sum(stop) != 3:
    model_list, flag = next_round_learn(model_list, cycle, rate, stop, flag)
    mse_list, stop = check_stop(mse_list, model_list)
# Out:
# Class 0 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=11.1008, mnll=-1171829.9442, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.018, mnll=-634.5873, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.0123, mnll=-341.4631, time=0.66 minutes
# >>> cycle=1, t=6000, mse=0.0101, mnll=-243.927, time=1.02 minutes
# >>> cycle=1, t=8000, mse=0.009, mnll=-195.2713, time=1.37 minutes
# >>> cycle=1, t=10000, mse=0.0083, mnll=-166.1528, time=1.7 minutes
# Class 1 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=6.4378, mnll=-1657881.6375, time=0.0 minutes
# >>> cycle=1, t=2000, mse=1.6918, mnll=-870.4479, time=0.34 minutes
# >>> cycle=1, t=4000, mse=1.6431, mnll=-457.9246, time=0.65 minutes
# >>> cycle=1, t=6000, mse=1.6292, mnll=-319.3345, time=1.0 minutes
# >>> cycle=1, t=8000, mse=1.6143, mnll=-250.8384, time=1.34 minutes
# >>> cycle=1, t=10000, mse=1.6084, mnll=-210.0229, time=1.69 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=4.0053, mnll=-2098545.0736, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.7582, mnll=-1099.2064, time=0.33 minutes
# >>> cycle=1, t=4000, mse=0.7187, mnll=-574.3274, time=0.68 minutes
# >>> cycle=1, t=6000, mse=0.6866, mnll=-399.4475, time=1.08 minutes
# >>> cycle=1, t=8000, mse=0.658, mnll=-312.0498, time=1.4 minutes
# >>> cycle=1, t=10000, mse=0.6311, mnll=-259.7013, time=1.73 minutes
# Class 0 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=10.8547, mnll=-2591957.333, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.0159, mnll=-1349.1011, time=0.32 minutes
# >>> cycle=1, t=4000, mse=0.0109, mnll=-700.3369, time=0.66 minutes
# >>> cycle=1, t=6000, mse=0.0091, mnll=-484.1689, time=1.0 minutes
# >>> cycle=1, t=8000, mse=0.0081, mnll=-376.1428, time=1.33 minutes
# >>> cycle=1, t=10000, mse=0.0075, mnll=-311.3631, time=1.66 minutes
# Class 1 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=7.0742, mnll=-3107474.4367, time=0.0 minutes
# >>> cycle=1, t=2000, mse=1.6495, mnll=-1599.4153, time=0.32 minutes
# >>> cycle=1, t=4000, mse=1.62, mnll=-823.6085, time=0.66 minutes
# >>> cycle=1, t=6000, mse=1.612, mnll=-563.6799, time=1.12 minutes
# >>> cycle=1, t=8000, mse=1.601, mnll=-434.4974, time=1.53 minutes
# >>> cycle=1, t=10000, mse=1.5958, mnll=-357.3712, time=1.92 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=3.1164, mnll=-3572377.4105, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.474, mnll=-1838.1506, time=0.42 minutes
# >>> cycle=1, t=4000, mse=0.4584, mnll=-944.7218, time=0.75 minutes
# >>> cycle=1, t=6000, mse=0.4329, mnll=-647.0216, time=1.07 minutes
# >>> cycle=1, t=8000, mse=0.4103, mnll=-498.247, time=1.4 minutes
# >>> cycle=1, t=10000, mse=0.3883, mnll=-409.0086, time=1.73 minutes
# Class 0 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=10.4688, mnll=-4083548.4803, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.0146, mnll=-2097.3136, time=0.31 minutes
# >>> cycle=1, t=4000, mse=0.01, mnll=-1075.2829, time=0.63 minutes
# >>> cycle=1, t=6000, mse=0.0084, mnll=-734.667, time=0.95 minutes
# >>> cycle=1, t=8000, mse=0.0075, mnll=-564.3983, time=1.26 minutes
# >>> cycle=1, t=10000, mse=0.0069, mnll=-462.2585, time=1.58 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=2.7998, mnll=-4620934.5851, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.3742, mnll=-2361.0839, time=0.31 minutes
# >>> cycle=1, t=4000, mse=0.3224, mnll=-1206.5709, time=0.63 minutes
# >>> cycle=1, t=6000, mse=0.2962, mnll=-821.9342, time=0.96 minutes
# >>> cycle=1, t=8000, mse=0.2796, mnll=-629.7247, time=1.3 minutes
# >>> cycle=1, t=10000, mse=0.2673, mnll=-514.4006, time=1.68 minutes
# Class 0 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=10.2209, mnll=-5136517.4503, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.0127, mnll=-2625.4203, time=0.32 minutes
# >>> cycle=1, t=4000, mse=0.0088, mnll=-1339.8677, time=0.68 minutes
# >>> cycle=1, t=6000, mse=0.0074, mnll=-911.3985, time=1.01 minutes
# >>> cycle=1, t=8000, mse=0.0067, mnll=-697.193, time=1.34 minutes
# >>> cycle=1, t=10000, mse=0.0063, mnll=-568.6836, time=1.65 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=1.9936, mnll=-5684231.6075, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.2912, mnll=-2894.5335, time=0.31 minutes
# >>> cycle=1, t=4000, mse=0.2512, mnll=-1473.8169, time=0.62 minutes
# >>> cycle=1, t=6000, mse=0.2327, mnll=-1000.4743, time=0.93 minutes
# >>> cycle=1, t=8000, mse=0.2232, mnll=-763.8657, time=1.23 minutes
# >>> cycle=1, t=10000, mse=0.2149, mnll=-621.8914, time=1.54 minutes
# Class 0 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=9.8222, mnll=-6210630.4862, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.0114, mnll=-3163.8689, time=0.31 minutes
# >>> cycle=1, t=4000, mse=0.0081, mnll=-1609.5154, time=0.61 minutes
# >>> cycle=1, t=6000, mse=0.0069, mnll=-1091.4378, time=0.92 minutes
# >>> cycle=1, t=8000, mse=0.0063, mnll=-832.4219, time=1.24 minutes
# >>> cycle=1, t=10000, mse=0.0059, mnll=-677.0213, time=1.57 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=1.4247, mnll=-6766294.0222, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.2077, mnll=-3437.6581, time=0.33 minutes
# >>> cycle=1, t=4000, mse=0.1914, mnll=-1745.8662, time=0.64 minutes
# >>> cycle=1, t=6000, mse=0.1828, mnll=-1182.0642, time=0.97 minutes
# >>> cycle=1, t=8000, mse=0.1783, mnll=-900.2587, time=1.3 minutes
# >>> cycle=1, t=10000, mse=0.1746, mnll=-731.1274, time=1.63 minutes
# Class 0 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=9.457, mnll=-7302314.1432, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.0108, mnll=-3710.8972, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.0077, mnll=-1883.3754, time=0.6 minutes
# >>> cycle=1, t=6000, mse=0.0066, mnll=-1274.2381, time=0.91 minutes
# >>> cycle=1, t=8000, mse=0.0061, mnll=-969.6886, time=1.22 minutes
# >>> cycle=1, t=10000, mse=0.0057, mnll=-786.9642, time=1.56 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=1.12, mnll=-7864218.7805, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.1658, mnll=-3988.0813, time=0.31 minutes
# >>> cycle=1, t=4000, mse=0.1576, mnll=-2021.3937, time=0.63 minutes
# >>> cycle=1, t=6000, mse=0.1524, mnll=-1365.9688, time=0.94 minutes
# >>> cycle=1, t=8000, mse=0.1507, mnll=-1038.3377, time=1.25 minutes
# >>> cycle=1, t=10000, mse=0.1485, mnll=-841.7175, time=1.57 minutes
# Class 0 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=9.2463, mnll=-8407339.3044, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.0108, mnll=-4264.1864, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.0077, mnll=-2160.3094, time=0.6 minutes
# >>> cycle=1, t=6000, mse=0.0066, mnll=-1459.0493, time=0.9 minutes
# >>> cycle=1, t=8000, mse=0.006, mnll=-1108.4355, time=1.21 minutes
# >>> cycle=1, t=10000, mse=0.0057, mnll=-898.0697, time=1.52 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=1.0531, mnll=-8974108.7903, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.1402, mnll=-4544.0974, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.1354, mnll=-2299.6895, time=0.61 minutes
# >>> cycle=1, t=6000, mse=0.1326, mnll=-1551.6627, time=0.92 minutes
# >>> cycle=1, t=8000, mse=0.1315, mnll=-1177.7375, time=1.23 minutes
# >>> cycle=1, t=10000, mse=0.1301, mnll=-953.3353, time=1.55 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=0.9698, mnll=-9525933.3522, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.1233, mnll=-4822.7132, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.1234, mnll=-2439.3024, time=0.61 minutes
# >>> cycle=1, t=6000, mse=0.1214, mnll=-1644.88, time=0.92 minutes
# >>> cycle=1, t=8000, mse=0.1205, mnll=-1247.7545, time=1.24 minutes
# >>> cycle=1, t=10000, mse=0.119, mnll=-1009.4188, time=1.56 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=0.9725, mnll=-10085996.8965, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.1126, mnll=-5103.4568, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.1123, mnll=-2579.8553, time=0.62 minutes
# >>> cycle=1, t=6000, mse=0.1104, mnll=-1738.6738, time=0.93 minutes
# >>> cycle=1, t=8000, mse=0.1105, mnll=-1318.1758, time=1.24 minutes
# >>> cycle=1, t=10000, mse=0.1092, mnll=-1065.8099, time=1.56 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=1.0665, mnll=-10649351.0698, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.1037, mnll=-5385.678, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.1046, mnll=-2721.0678, time=0.6 minutes
# >>> cycle=1, t=6000, mse=0.1033, mnll=-1832.8934, time=0.91 minutes
# >>> cycle=1, t=8000, mse=0.1028, mnll=-1388.9062, time=1.23 minutes
# >>> cycle=1, t=10000, mse=0.1017, mnll=-1122.4359, time=1.54 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=1.1571, mnll=-11215175.3622, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.0984, mnll=-5669.035, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.098, mnll=-2862.8467, time=0.6 minutes
# >>> cycle=1, t=6000, mse=0.0975, mnll=-1927.4586, time=0.9 minutes
# >>> cycle=1, t=8000, mse=0.0967, mnll=-1459.8797, time=1.21 minutes
# >>> cycle=1, t=10000, mse=0.0961, mnll=-1179.2487, time=1.52 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=1.1345, mnll=-11782844.4205, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.0931, mnll=-5953.259, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.0936, mnll=-3005.0667, time=0.6 minutes
# >>> cycle=1, t=6000, mse=0.0926, mnll=-2022.3391, time=0.9 minutes
# >>> cycle=1, t=8000, mse=0.0919, mnll=-1531.0862, time=1.21 minutes
# >>> cycle=1, t=10000, mse=0.0912, mnll=-1236.2461, time=1.53 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=1.1107, mnll=-12352728.9799, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.093, mnll=-6238.3569, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.0912, mnll=-3147.7316, time=0.6 minutes
# >>> cycle=1, t=6000, mse=0.0903, mnll=-2117.5136, time=0.9 minutes
# >>> cycle=1, t=8000, mse=0.0894, mnll=-1602.5195, time=1.21 minutes
# >>> cycle=1, t=10000, mse=0.0884, mnll=-1293.4366, time=1.52 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=1.2166, mnll=-12924509.4969, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.0856, mnll=-6524.5235, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.0857, mnll=-3290.9034, time=0.6 minutes
# >>> cycle=1, t=6000, mse=0.0849, mnll=-2213.0203, time=0.9 minutes
# >>> cycle=1, t=8000, mse=0.0852, mnll=-1674.1769, time=1.21 minutes
# >>> cycle=1, t=10000, mse=0.085, mnll=-1350.7771, time=1.52 minutes
# Class 2 starts learning
# >>> relearn
# >>> cycle=1, t=1, mse=1.3126, mnll=-13498125.56, time=0.0 minutes
# >>> cycle=1, t=2000, mse=0.0868, mnll=-6811.33, time=0.3 minutes
# >>> cycle=1, t=4000, mse=0.0867, mnll=-3434.393, time=0.61 minutes
# >>> cycle=1, t=6000, mse=0.0854, mnll=-2308.7309, time=0.93 minutes
# >>> cycle=1, t=8000, mse=0.0845, mnll=-1745.9895, time=1.26 minutes
# >>> cycle=1, t=10000, mse=0.0835, mnll=-1408.2646, time=1.6 minutes

# %%
cwd = os.getcwd()
model_path = os.path.join(cwd, "models", "train_2.pickle")
with open(model_path, 'wb') as f:
    pickle.dump(model_list, f)
