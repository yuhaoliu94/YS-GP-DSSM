# %%
import os
import pickle
os.getcwd()
os.chdir("../../")

import numpy as np
from matplotlib import pyplot as plt

# %%
from src.gpdssm.models import StandardSingleModel, YuleSimonSingleModel
from src.gpdssm.models_ys import ModelLayer, YuleSimonModel
from src.gpdssm.utils import normalize_weights

# %%
def mean_average(states, N=100):
    return np.convolve(states, np.ones(N)/N, mode='valid')

# %%
cwd = os.getcwd()
model_path = os.path.join(cwd, "models", "train_2.pickle")
with open(model_path, 'rb') as f:
    model_list = pickle.load(f)

# %%
cwd = os.getcwd()
Z_path = os.path.join(cwd, "folds", "test_2_fold_1_Z.txt")
with open(Z_path, 'rb') as f:
    Z_act = pickle.load(f)

# %%
C = 3

# %%
ys_single_model_list = []


for i in range(C):
    param = {"data_name": model_list[i].data_name,
             "data_fold": model_list[i].data_fold,
             "dim_hidden": model_list[i].dim_hidden,
             "num_rff": model_list[i].J,
             "num_particle": 1000, # model_list[i].M,
             "display_step": model_list[i].display_step,
             "warm_start": model_list[i].warm_start,
             "learning_rate": model_list[i].learning_rate,
             "num_train_cycle": model_list[i].num_train_cycle,
            }
    
    ys_single_model = YuleSimonSingleModel(C, **param)
    ys_single_model.initialize_structure_from_functions(model_list[i].functions[:-1], model_list[-1].functions[-1])
    ys_single_model_list.append(ys_single_model)

# %%
a0 = np.array([5] * C)
b0 = np.array([1] * C)
ys_model = YuleSimonModel(data_name="test_2", data_fold=1, model_list=ys_single_model_list,
                         num_rff=50, num_particle=1000, a0=a0, b0=b0,
                         display_step=100, warm_start=0, learning_rate=0.001, num_train_cycle=1)

# %%
ys_model.learn()
# Out:
# >>> train cycle 1
# >>> cycle=1, t=1, mse=5.8563, mnll=983.2002, time=0.0 minutes
# >>> cycle=1, t=100, mse=8.9469, mnll=1985.2146, time=0.04 minutes
# >>> cycle=1, t=200, mse=9.3366, mnll=2004.7459, time=0.08 minutes
# >>> cycle=1, t=300, mse=8.7337, mnll=1977.9212, time=0.12 minutes
# >>> cycle=1, t=400, mse=8.8707, mnll=1948.12, time=0.16 minutes
# >>> cycle=1, t=500, mse=8.7478, mnll=1917.3775, time=0.2 minutes
# >>> cycle=1, t=600, mse=8.8202, mnll=1914.1539, time=0.24 minutes
# >>> cycle=1, t=700, mse=8.6398, mnll=1878.3486, time=0.29 minutes
# >>> cycle=1, t=800, mse=8.5424, mnll=1872.8278, time=0.33 minutes
# >>> cycle=1, t=900, mse=8.4861, mnll=1855.8379, time=0.37 minutes
# >>> cycle=1, t=1000, mse=8.4137, mnll=1846.9441, time=0.42 minutes
# >>> cycle=1, t=1100, mse=8.1348, mnll=1783.155, time=0.46 minutes
# >>> cycle=1, t=1200, mse=7.9566, mnll=1705.983, time=0.51 minutes
# >>> cycle=1, t=1300, mse=7.8195, mnll=1635.4182, time=0.56 minutes
# >>> cycle=1, t=1400, mse=7.6753, mnll=1597.6931, time=0.6 minutes
# >>> cycle=1, t=1500, mse=7.4788, mnll=1571.1051, time=0.65 minutes
# >>> cycle=1, t=1600, mse=7.3404, mnll=1534.9775, time=0.71 minutes
# >>> cycle=1, t=1700, mse=7.1951, mnll=1511.7953, time=0.76 minutes
# >>> cycle=1, t=1800, mse=7.0478, mnll=1494.9276, time=0.81 minutes
# >>> cycle=1, t=1900, mse=6.9414, mnll=1486.4616, time=0.87 minutes
# >>> cycle=1, t=2000, mse=6.8372, mnll=1464.3845, time=0.92 minutes
# >>> cycle=1, t=2100, mse=6.7373, mnll=1447.2089, time=0.98 minutes
# >>> cycle=1, t=2200, mse=6.6716, mnll=1445.4572, time=1.04 minutes
# >>> cycle=1, t=2300, mse=6.6185, mnll=1432.0783, time=1.1 minutes
# >>> cycle=1, t=2400, mse=6.5615, mnll=1425.0862, time=1.16 minutes
# >>> cycle=1, t=2500, mse=6.4753, mnll=1416.5826, time=1.23 minutes
# >>> cycle=1, t=2600, mse=6.3844, mnll=1401.3945, time=1.29 minutes
# >>> cycle=1, t=2700, mse=6.3606, mnll=1380.1751, time=1.36 minutes
# >>> cycle=1, t=2800, mse=6.3106, mnll=1363.8822, time=1.43 minutes
# >>> cycle=1, t=2900, mse=6.2684, mnll=1357.5947, time=1.5 minutes
# >>> cycle=1, t=3000, mse=6.2225, mnll=1354.7436, time=1.57 minutes
# >>> cycle=1, t=3100, mse=6.1641, mnll=1342.5376, time=1.65 minutes
# >>> cycle=1, t=3200, mse=6.1099, mnll=1327.3333, time=1.72 minutes
# >>> cycle=1, t=3300, mse=6.0657, mnll=1315.0397, time=1.8 minutes
# >>> cycle=1, t=3400, mse=6.0066, mnll=1304.4904, time=1.88 minutes
# >>> cycle=1, t=3500, mse=5.9552, mnll=1297.0612, time=1.96 minutes
# >>> cycle=1, t=3600, mse=5.9216, mnll=1286.1401, time=2.05 minutes
# >>> cycle=1, t=3700, mse=5.8768, mnll=1275.5607, time=2.13 minutes
# >>> cycle=1, t=3800, mse=5.8387, mnll=1266.6672, time=2.22 minutes
# >>> cycle=1, t=3900, mse=5.7989, mnll=1255.7379, time=2.3 minutes
# >>> cycle=1, t=4000, mse=5.7557, mnll=1247.5042, time=2.39 minutes
# >>> cycle=1, t=4100, mse=5.7088, mnll=1238.6557, time=2.48 minutes
# >>> cycle=1, t=4200, mse=5.6615, mnll=1231.7663, time=2.57 minutes
# >>> cycle=1, t=4300, mse=5.6071, mnll=1225.96, time=2.66 minutes
# >>> cycle=1, t=4400, mse=5.5642, mnll=1219.1165, time=2.75 minutes
# >>> cycle=1, t=4500, mse=5.5281, mnll=1214.5446, time=2.85 minutes
# >>> cycle=1, t=4600, mse=5.4926, mnll=1208.365, time=2.94 minutes
# >>> cycle=1, t=4700, mse=5.4745, mnll=1201.8442, time=3.04 minutes
# >>> cycle=1, t=4800, mse=5.4498, mnll=1194.2388, time=3.13 minutes
# >>> cycle=1, t=4900, mse=5.4237, mnll=1188.9725, time=3.23 minutes
# >>> cycle=1, t=5000, mse=5.3928, mnll=1182.8646, time=3.33 minutes
# >>> cycle=1, t=5100, mse=5.416, mnll=1188.5999, time=3.43 minutes
# >>> cycle=1, t=5200, mse=5.4371, mnll=1204.258, time=3.53 minutes
# >>> cycle=1, t=5300, mse=5.4605, mnll=1211.1494, time=3.64 minutes
# >>> cycle=1, t=5400, mse=5.4611, mnll=1220.2145, time=3.74 minutes
# >>> cycle=1, t=5500, mse=5.4731, mnll=1230.0525, time=3.84 minutes
# >>> cycle=1, t=5600, mse=5.4724, mnll=1232.4473, time=3.95 minutes
# >>> cycle=1, t=5700, mse=5.491, mnll=1231.5663, time=4.05 minutes
# >>> cycle=1, t=5800, mse=5.509, mnll=1241.5488, time=4.16 minutes
# >>> cycle=1, t=5900, mse=5.5265, mnll=1247.0226, time=4.27 minutes
# >>> cycle=1, t=6000, mse=5.5206, mnll=1250.4418, time=4.38 minutes
# >>> cycle=1, t=6100, mse=5.4926, mnll=1243.8488, time=4.5 minutes
# >>> cycle=1, t=6200, mse=5.4663, mnll=1237.9231, time=4.61 minutes
# >>> cycle=1, t=6300, mse=5.46, mnll=1234.1222, time=4.73 minutes
# >>> cycle=1, t=6400, mse=5.4409, mnll=1229.0976, time=4.85 minutes
# >>> cycle=1, t=6500, mse=5.4145, mnll=1225.5824, time=4.97 minutes
# >>> cycle=1, t=6600, mse=5.3965, mnll=1221.9982, time=5.09 minutes
# >>> cycle=1, t=6700, mse=5.3802, mnll=1217.9961, time=5.21 minutes
# >>> cycle=1, t=6800, mse=5.3533, mnll=1213.9681, time=5.33 minutes
# >>> cycle=1, t=6900, mse=5.3383, mnll=1210.1548, time=5.46 minutes
# >>> cycle=1, t=7000, mse=5.3164, mnll=1205.8627, time=5.58 minutes
# >>> cycle=1, t=7100, mse=5.302, mnll=1202.975, time=5.71 minutes
# >>> cycle=1, t=7200, mse=5.2902, mnll=1198.4065, time=5.83 minutes
# >>> cycle=1, t=7300, mse=5.2771, mnll=1192.7164, time=5.96 minutes
# >>> cycle=1, t=7400, mse=5.2681, mnll=1189.5636, time=6.09 minutes
# >>> cycle=1, t=7500, mse=5.2663, mnll=1188.5042, time=6.22 minutes
# >>> cycle=1, t=7600, mse=5.2485, mnll=1185.2957, time=6.35 minutes
# >>> cycle=1, t=7700, mse=5.2273, mnll=1180.6819, time=6.49 minutes
# >>> cycle=1, t=7800, mse=5.2112, mnll=1177.8982, time=6.62 minutes
# >>> cycle=1, t=7900, mse=5.2042, mnll=1174.8442, time=6.76 minutes
# >>> cycle=1, t=8000, mse=5.1934, mnll=1171.1065, time=6.89 minutes
# >>> cycle=1, t=8100, mse=5.1761, mnll=1167.1929, time=7.03 minutes
# >>> cycle=1, t=8200, mse=5.1556, mnll=1163.4511, time=7.17 minutes
# >>> cycle=1, t=8300, mse=5.1515, mnll=1160.9607, time=7.31 minutes
# >>> cycle=1, t=8400, mse=5.1442, mnll=1158.5534, time=7.45 minutes
# >>> cycle=1, t=8500, mse=5.132, mnll=1156.1966, time=7.59 minutes
# >>> cycle=1, t=8600, mse=5.1172, mnll=1153.217, time=7.73 minutes
# >>> cycle=1, t=8700, mse=5.1004, mnll=1150.5134, time=7.87 minutes
# >>> cycle=1, t=8800, mse=5.089, mnll=1148.2745, time=8.02 minutes
# >>> cycle=1, t=8900, mse=5.0773, mnll=1145.9806, time=8.17 minutes
# >>> cycle=1, t=9000, mse=5.0741, mnll=1145.084, time=8.32 minutes
# >>> cycle=1, t=9100, mse=5.0882, mnll=1147.3691, time=8.47 minutes
# >>> cycle=1, t=9200, mse=5.1174, mnll=1154.8805, time=8.61 minutes
# >>> cycle=1, t=9300, mse=5.133, mnll=1156.3652, time=8.76 minutes
# >>> cycle=1, t=9400, mse=5.1462, mnll=1163.9054, time=8.91 minutes
# >>> cycle=1, t=9500, mse=5.155, mnll=1172.4178, time=9.06 minutes
# >>> cycle=1, t=9600, mse=5.2197, mnll=1183.8614, time=9.21 minutes
# >>> cycle=1, t=9700, mse=5.2971, mnll=1195.8489, time=9.36 minutes
# >>> cycle=1, t=9800, mse=5.3499, mnll=1207.2841, time=9.52 minutes
# >>> cycle=1, t=9900, mse=5.3794, mnll=1215.5939, time=9.67 minutes
# >>> cycle=1, t=10000, mse=5.4428, mnll=1226.676, time=9.83 minutes

# %%
ys_layer = ys_model.ys_layer
stored_states = np.array(ys_layer.stored_states)
stored_states = np.array(stored_states[1:, :])
stored_particle_states = np.array(ys_layer.stored_particle_states)

# %%
stored_states_ma = np.array([mean_average(stored_states[:, i]) for i in range(C)]).T

# %%
plt.plot(stored_states[:, 0], label = "Predicted Prob of Class 0")
plt.savefig(os.path.join(cwd, "plots", "case2", "raw_est_prob_for_class_0.png"))

# %%
plt.plot(stored_states[:, 1], label = "Predicted Prob of Class 1")
plt.savefig(os.path.join(cwd, "plots", "case2", "raw_est_prob_for_class_1.png"))

# %%
plt.plot(stored_states[:, 2], label = "Predicted Prob of Class 2")
plt.savefig(os.path.join(cwd, "plots", "case2", "raw_est_prob_for_class_2.png"))

# %%
plt.plot(stored_states_ma[:, 0], label = "Predicted Prob of Class 0")
plt.plot(stored_states_ma[:, 1], label = "Predicted Prob of Class 1")
plt.plot(stored_states_ma[:, 2], label = "Predicted Prob of Class 2")
plt.legend()
plt.savefig(os.path.join(cwd, "plots", "case2", "ma_est_prob.png"))

# %%
argmax = np.argmax(stored_states_ma, axis=1)
plt.plot(argmax, label = "Predicted Class")
plt.plot(Z_act[99:], label = "Actual Class")
plt.legend()
plt.savefig(os.path.join(cwd, "plots", "case2", "arg_ma_est_prob.png"))

# %%
argmax = np.argmax(stored_states, axis=1)
plt.plot(mean_average(argmax), label = "Predicted Class")
plt.plot(Z_act[99:], label = "Actual Class")
plt.legend()
plt.savefig(os.path.join(cwd, "plots", "case2", "ma_arg_est_prob.png"))

# %%
pred = np.array(ys_model.ensemble_observation_layer.stored_states)

# %%
obs = ys_model.data.Y

# %%
for d in range(ys_model.data.Dy):
    start = -101
    end = start +100
    plt.plot(obs[start:end,d], label='obs')
    plt.plot(pred[start:end,d], label='pred')
    plt.legend()
    plt.show()
