# %%
import os
import pickle
os.getcwd()
os.chdir("../")

import numpy as np
from matplotlib import pyplot as plt

# %%
from src.gpdssm.models import StandardSingleModel, YuleSimonSingleModel
from src.gpdssm.models_ys import ModelLayer, YuleSimonModel
from src.gpdssm.utils import normalize_weights

# %%
def mean_average(states, N=100):
    return np.convolve(states, np.ones(N)/N, mode='valid')

# %%
cwd = os.getcwd()
model_path = os.path.join(cwd, "models", "train_2.pickle")
with open(model_path, 'rb') as f:
    model_list = pickle.load(f)

# %%
cwd = os.getcwd()
Z_path = os.path.join(cwd, "folds", "test_fold_21_Z.txt")
with open(Z_path, 'rb') as f:
    Z_act = pickle.load(f)

# %%
C = 3

# %%
ys_single_model_list = []


for i in range(C):
    param = {"data_name": model_list[i].data_name,
             "data_fold": model_list[i].data_fold,
             "dim_hidden": model_list[i].dim_hidden,
             "num_rff": model_list[i].J,
             "num_particle": 1000, #model_list[i].M,
             "display_step": model_list[i].display_step,
             "warm_start": model_list[i].warm_start,
             "learning_rate": model_list[i].learning_rate,
             "num_train_cycle": model_list[i].num_train_cycle,
            }
    
    ys_single_model = YuleSimonSingleModel(C, **param)
    ys_single_model.initialize_structure_from_functions(model_list[i].functions[:-1], model_list[-1].functions[-1])
    ys_single_model_list.append(ys_single_model)

# %%
a0 = np.array([5] * C)
b0 = np.array([1] * C)
ys_model = YuleSimonModel(data_name="test", data_fold=21, model_list=ys_single_model_list,
                         num_rff=50, num_particle=1000, a0=a0, b0=b0,
                         display_step=100, warm_start=0, learning_rate=0.001, num_train_cycle=1)

# %%
ys_model.learn()
# Out:
# >>> train cycle 1
# >>> cycle=1, t=1, mse=10.5014, mnll=1497.4005, time=0.0 minutes
# >>> cycle=1, t=100, mse=1.1352, mnll=573.8939, time=0.03 minutes
# >>> cycle=1, t=200, mse=0.7426, mnll=525.6174, time=0.07 minutes
# >>> cycle=1, t=300, mse=0.5807, mnll=512.8193, time=0.1 minutes
# >>> cycle=1, t=400, mse=0.5351, mnll=496.2997, time=0.14 minutes
# >>> cycle=1, t=500, mse=0.5055, mnll=489.1362, time=0.17 minutes
# >>> cycle=1, t=600, mse=0.4674, mnll=490.9814, time=0.21 minutes
# >>> cycle=1, t=700, mse=0.442, mnll=490.5176, time=0.25 minutes
# >>> cycle=1, t=800, mse=0.4226, mnll=492.3555, time=0.29 minutes
# >>> cycle=1, t=900, mse=0.4059, mnll=494.2293, time=0.33 minutes
# >>> cycle=1, t=1000, mse=0.3974, mnll=491.5233, time=0.37 minutes
# >>> cycle=1, t=1100, mse=1.1886, mnll=489.116, time=0.41 minutes
# >>> cycle=1, t=1200, mse=1.6466, mnll=475.8084, time=0.45 minutes
# >>> cycle=1, t=1300, mse=2.1641, mnll=475.6852, time=0.5 minutes
# >>> cycle=1, t=1400, mse=2.7691, mnll=485.7417, time=0.54 minutes
# >>> cycle=1, t=1500, mse=3.0514, mnll=485.2263, time=0.59 minutes
# >>> cycle=1, t=1600, mse=3.3985, mnll=483.8588, time=0.64 minutes
# >>> cycle=1, t=1700, mse=3.7896, mnll=479.4245, time=0.69 minutes
# >>> cycle=1, t=1800, mse=3.941, mnll=476.1378, time=0.74 minutes
# >>> cycle=1, t=1900, mse=4.0933, mnll=473.5789, time=0.79 minutes
# >>> cycle=1, t=2000, mse=4.2691, mnll=474.1783, time=0.84 minutes
# >>> cycle=1, t=2100, mse=4.2721, mnll=486.5216, time=0.89 minutes
# >>> cycle=1, t=2200, mse=4.2084, mnll=497.7927, time=0.95 minutes
# >>> cycle=1, t=2300, mse=4.158, mnll=511.9298, time=1.01 minutes
# >>> cycle=1, t=2400, mse=4.1059, mnll=521.7381, time=1.07 minutes
# >>> cycle=1, t=2500, mse=4.0391, mnll=532.1182, time=1.13 minutes
# >>> cycle=1, t=2600, mse=3.9909, mnll=541.4892, time=1.19 minutes
# >>> cycle=1, t=2700, mse=3.9395, mnll=549.4519, time=1.26 minutes
# >>> cycle=1, t=2800, mse=3.8867, mnll=559.2239, time=1.32 minutes
# >>> cycle=1, t=2900, mse=3.8545, mnll=563.3905, time=1.39 minutes
# >>> cycle=1, t=3000, mse=3.8078, mnll=569.8125, time=1.46 minutes
# >>> cycle=1, t=3100, mse=3.8535, mnll=568.6201, time=1.53 minutes
# >>> cycle=1, t=3200, mse=3.8695, mnll=567.4735, time=1.6 minutes
# >>> cycle=1, t=3300, mse=3.8461, mnll=566.2973, time=1.67 minutes
# >>> cycle=1, t=3400, mse=3.8121, mnll=567.1579, time=1.75 minutes
# >>> cycle=1, t=3500, mse=3.8143, mnll=567.8209, time=1.82 minutes
# >>> cycle=1, t=3600, mse=3.7762, mnll=567.5277, time=1.9 minutes
# >>> cycle=1, t=3700, mse=3.8457, mnll=574.3788, time=1.98 minutes
# >>> cycle=1, t=3800, mse=3.838, mnll=573.4322, time=2.05 minutes
# >>> cycle=1, t=3900, mse=3.8614, mnll=573.3386, time=2.13 minutes
# >>> cycle=1, t=4000, mse=3.8637, mnll=578.191, time=2.22 minutes
# >>> cycle=1, t=4100, mse=3.7956, mnll=577.6463, time=2.31 minutes
# >>> cycle=1, t=4200, mse=3.7153, mnll=574.7629, time=2.4 minutes
# >>> cycle=1, t=4300, mse=3.6393, mnll=573.1212, time=2.49 minutes
# >>> cycle=1, t=4400, mse=3.5638, mnll=570.735, time=2.58 minutes
# >>> cycle=1, t=4500, mse=3.4924, mnll=568.1557, time=2.68 minutes
# >>> cycle=1, t=4600, mse=3.427, mnll=566.2381, time=2.78 minutes
# >>> cycle=1, t=4700, mse=3.3595, mnll=565.1946, time=2.88 minutes
# >>> cycle=1, t=4800, mse=3.2968, mnll=563.7511, time=2.98 minutes
# >>> cycle=1, t=4900, mse=3.235, mnll=562.3048, time=3.08 minutes
# >>> cycle=1, t=5000, mse=3.1768, mnll=560.921, time=3.18 minutes

# %%
ys_layer = ys_model.ys_layer
stored_states = np.array(ys_layer.stored_states)
stored_states = np.array(stored_states[1:, :])
stored_particle_states = np.array(ys_layer.stored_particle_states)

# %%
stored_states_ma = np.array([mean_average(stored_states[:, i]) for i in range(C)]).T

# %%
plt.plot(stored_states[:, 0], label = "Predicted Prob of Class 0")
plt.savefig(os.path.join(cwd, "plots", "case2", "raw_est_prob_for_class_0.png"))

# %%
plt.plot(stored_states[:, 1], label = "Predicted Prob of Class 0")
plt.savefig(os.path.join(cwd, "plots", "case2", "raw_est_prob_for_class_1.png"))

# %%
plt.plot(stored_states[:, 2], label = "Predicted Prob of Class 0")
plt.savefig(os.path.join(cwd, "plots", "case2", "raw_est_prob_for_class_2.png"))

# %%
plt.plot(stored_states_ma[:, 0], label = "Predicted Prob of Class 0")
plt.plot(stored_states_ma[:, 1], label = "Predicted Prob of Class 1")
plt.plot(stored_states_ma[:, 2], label = "Predicted Prob of Class 2")
plt.legend()
plt.savefig(os.path.join(cwd, "plots", "case2", "ma_est_prob.png"))

# %%
argmax = np.argmax(stored_states_ma, axis=1)
plt.plot(argmax, label = "Predicted Class")
plt.plot(Z_act[99:], label = "Actual Class")
plt.legend()
plt.savefig(os.path.join(cwd, "plots", "case2", "arg_ma_est_prob.png"))

# %%
argmax = np.argmax(stored_states, axis=1)
plt.plot(mean_average(argmax), label = "Predicted Class")
plt.plot(Z_act[99:], label = "Actual Class")
plt.legend()
plt.savefig(os.path.join(cwd, "plots", "case2", "ma_arg_est_prob.png"))

# %%
pred = np.array(ys_model.ensemble_observation_layer.stored_states)

# %%
obs = ys_model.data.Y

# %%
for d in range(10):
    start = 4900
    end = start +100
    plt.plot(obs[start:end,d], label='obs')
    plt.plot(pred[start:end,d], label='pred')
    plt.legend()
    plt.show()
