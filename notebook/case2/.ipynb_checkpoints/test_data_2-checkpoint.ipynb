# %%
import os
import pickle
import numpy as np
from matplotlib import pyplot as plt

os.chdir("../../")

from src.gpdssm.utils import get_random_state

# %%
Dx = 2
Dy = 50
T = 20000
C = 3
init_num = 1
X = [[0.0, 0.0]]
Y = []

random_state = get_random_state()
A = random_state.normal(0, 1, (Dy, Dx))
B = random_state.beta(1, 1, (Dy, Dx))
Z = np.zeros(T)
print(A)
print(B)
# Out:
# [[-1.41094505e+00 -2.80321885e-01]
#  [-3.49476510e-02 -3.00443785e-01]
#  [-1.30650098e+00  1.08115439e+00]
#  [-1.62934508e-01 -5.68812466e-01]
#  [-6.06946957e-01 -6.14147721e-01]
#  [-6.59852936e-01 -7.31361145e-02]
#  [-3.50689921e-02 -4.70741840e-01]
#  [ 1.72573683e+00  1.56441685e+00]
#  [-3.12845275e-01 -1.43760243e+00]
#  [-6.27151230e-03 -4.24614769e-01]
#  [-8.94513503e-01 -6.82504622e-01]
#  [-9.47097277e-01 -9.70867672e-01]
#  [-1.03459541e-01  4.93394488e-01]
#  [-4.80543416e-01  4.49944350e-01]
#  [-6.34668571e-01 -2.45414318e-01]
#  [ 1.20007440e-02  1.91571160e+00]
#  [-6.77052516e-01 -1.46859077e+00]
#  [-3.01300644e+00  6.44066326e-02]
#  [-7.88363121e-01  3.00493659e-02]
#  [ 9.98072138e-01 -8.38045130e-01]
#  [-9.07778725e-01  6.04390614e-01]
#  [-5.49722148e-02 -2.40686283e-01]
#  [-7.92525545e-01  1.29300336e+00]
#  [-1.02064858e+00  1.19017390e+00]
#  [-7.51692405e-02 -3.84422949e-01]
#  [ 8.58159979e-01  3.56063267e-01]
#  [ 7.50625904e-01  4.10899352e-01]
#  [ 1.25543320e+00  2.51531038e-03]
#  [ 5.96420671e-01  1.08121903e+00]
#  [ 1.39038741e+00  1.06513681e+00]
#  [ 1.55795469e+00  5.29381856e-01]
#  [-6.23296071e-01  2.37226192e+00]
#  [-7.48136287e-01  7.59661280e-02]
#  [ 9.60923187e-01 -7.30432629e-01]
#  [-9.72064921e-01  4.58552654e-01]
#  [-1.06940818e+00  5.55771091e-01]
#  [-5.26711229e-01  4.05751549e-01]
#  [ 2.96926506e-01 -7.39240023e-01]
#  [-4.60453951e-01 -7.19272763e-01]
#  [ 1.43292584e+00  9.80736268e-01]
#  [ 1.76377880e+00 -7.46298813e-01]
#  [ 6.52603044e-01  2.83798877e-01]
#  [-3.18400443e+00  2.83399508e-02]
#  [-3.93713856e-01  1.24735604e+00]
#  [ 1.02066311e+00  1.29238722e+00]
#  [ 1.60089848e+00  5.83405190e-01]
#  [ 3.53004868e-01  1.38383800e+00]
#  [ 2.98131666e-01 -1.96852970e-01]
#  [ 1.12389007e+00  1.31404395e+00]
#  [-1.55156963e+00 -4.38598028e-01]]
# [[0.58951191 0.57725173]
#  [0.5220166  0.98525997]
#  [0.6715595  0.36625659]
#  [0.81886102 0.41442334]
#  [0.73857791 0.64453103]
#  [0.15681409 0.1812051 ]
#  [0.25109472 0.80109444]
#  [0.1796397  0.32426915]
#  [0.40133216 0.2486558 ]
#  [0.21145223 0.23560404]
#  [0.89322106 0.09208449]
#  [0.82093847 0.34403638]
#  [0.06732326 0.05337572]
#  [0.55172717 0.30936989]
#  [0.73296877 0.8071538 ]
#  [0.85404412 0.96822462]
#  [0.19397056 0.57958195]
#  [0.97281605 0.19488193]
#  [0.77302059 0.13640719]
#  [0.3274308  0.19930693]
#  [0.81169243 0.37315566]
#  [0.13048262 0.69834434]
#  [0.55997589 0.34739433]
#  [0.01218509 0.37401495]
#  [0.51928743 0.0718975 ]
#  [0.83230127 0.32364347]
#  [0.44262642 0.75695333]
#  [0.86890358 0.47253135]
#  [0.67701323 0.73262673]
#  [0.86787009 0.58635967]
#  [0.55238237 0.84652785]
#  [0.81596276 0.84594167]
#  [0.37874967 0.16462852]
#  [0.02032107 0.79787296]
#  [0.95023427 0.79221021]
#  [0.47478982 0.66516515]
#  [0.46490917 0.49689301]
#  [0.81514438 0.44448255]
#  [0.87736584 0.45081353]
#  [0.19206615 0.05487156]
#  [0.34012485 0.55254877]
#  [0.77057703 0.22989095]
#  [0.3456352  0.96227765]
#  [0.28247015 0.23159794]
#  [0.41204224 0.41228841]
#  [0.72495929 0.62250815]
#  [0.38682961 0.56754794]
#  [0.75219957 0.93015535]
#  [0.75041307 0.98511079]
#  [0.23626002 0.78011123]]

# %%
def generate_z_process(T):
    cut_point = np.array([2,6,10,12,18,19]) * 1000 #np.sort(random_state.choice(np.arange(T), 4, replace=False))
    Z[:cut_point[0]] = 0
    Z[cut_point[0]:cut_point[1]] = 1
    Z[cut_point[1]:cut_point[2]] = 2
    Z[cut_point[2]:cut_point[3]] = 1
    Z[cut_point[3]:cut_point[4]] = 2
    Z[cut_point[4]:cut_point[5]] = 1
    Z[cut_point[-1]:] = 0

# %%
generate_z_process(T)
Z = np.array(Z)

# %%
plt.plot(Z)

# %%
def x_process_1(x):
    x_next_1 = 0.9 * x[0] + 0.5 * np.sin(x[1]) + random_state.normal(0., 1.0e-2)
    x_next_2 = 0.5 * np.cos(x[0]) + 0.9 * x[1] + random_state.normal(0., 1.0e-2)
    return [x_next_1, x_next_2]

def generate_x_process_1(T):
    x_next = x_process_1(X[-1])
    X.append(x_next)

# %%
def x_process_2(x):
    x_next_1 = 0.9 * x[0] - 0.5 * np.sin(50 * x[0] * x[1]) + random_state.normal(0., 1.0e-2)
    x_next_2 = 0.5 * np.cos(50 * x[0] * x[1]) - 0.9 * x[1] + random_state.normal(0., 1.0e-2)
    return [x_next_1, x_next_2]

def generate_x_process_2(T):
    for t in range(T):
        x_next = x_process_2(X[-1])
        X.append(x_next)

# %%
def x_process_3(x):
    x_next_1 = 0.9 * x[0] + 0.5 * np.sin(3 * x[1]) + random_state.normal(0., 1.0e-2)
    x_next_2 = 0.5 * np.sin(4 * x[0] + 1) + 0.9 * x[1] + random_state.normal(0., 1.0e-2)
    return [x_next_1, x_next_2]

def generate_x_process_3(T):
    for t in range(T):
        x_next = x_process_3(X[-1])
        X.append(x_next)

# %%
def y_process(x):
    y = 0.5 * np.dot(A, x) + np.sin(np.dot(B, x)) + np.random.normal(0., 0.01, Dy)
    return y

def generate_y_process(T):
    for t in range(T):
        y_next = y_process(X[t+1])
        Y.append(y_next)

# %%
generate_x = [generate_x_process_1, generate_x_process_2, generate_x_process_3]

# %%
for i in Z:
    generate_x[int(i)](1)
X = np.array(X)

# %%
plt.plot(X)
# Out:
# [<matplotlib.lines.Line2D at 0x1b42ed71090>,
#  <matplotlib.lines.Line2D at 0x1b4305e4ad0>]

# %%
generate_y_process(T)
Y = np.array(Y)

# %%
plt.plot(Y)
# Out:
# [<matplotlib.lines.Line2D at 0x1b430639290>,
#  <matplotlib.lines.Line2D at 0x1b43065d110>,
#  <matplotlib.lines.Line2D at 0x1b43065d4d0>,
#  <matplotlib.lines.Line2D at 0x1b43065d950>,
#  <matplotlib.lines.Line2D at 0x1b43065dd10>,
#  <matplotlib.lines.Line2D at 0x1b43065e250>,
#  <matplotlib.lines.Line2D at 0x1b43065e6d0>,
#  <matplotlib.lines.Line2D at 0x1b43065eb50>,
#  <matplotlib.lines.Line2D at 0x1b43065dc90>,
#  <matplotlib.lines.Line2D at 0x1b430635a50>,
#  <matplotlib.lines.Line2D at 0x1b43061f790>,
#  <matplotlib.lines.Line2D at 0x1b430634090>,
#  <matplotlib.lines.Line2D at 0x1b43065ff90>,
#  <matplotlib.lines.Line2D at 0x1b4306384d0>,
#  <matplotlib.lines.Line2D at 0x1b4306687d0>,
#  <matplotlib.lines.Line2D at 0x1b430638d50>,
#  <matplotlib.lines.Line2D at 0x1b430669050>,
#  <matplotlib.lines.Line2D at 0x1b4306694d0>,
#  <matplotlib.lines.Line2D at 0x1b430669ad0>,
#  <matplotlib.lines.Line2D at 0x1b430669c90>,
#  <matplotlib.lines.Line2D at 0x1b43066a2d0>,
#  <matplotlib.lines.Line2D at 0x1b43066a5d0>,
#  <matplotlib.lines.Line2D at 0x1b430781150>,
#  <matplotlib.lines.Line2D at 0x1b430781510>,
#  <matplotlib.lines.Line2D at 0x1b43066b190>,
#  <matplotlib.lines.Line2D at 0x1b43063b750>,
#  <matplotlib.lines.Line2D at 0x1b42ed18890>,
#  <matplotlib.lines.Line2D at 0x1b43060bf90>,
#  <matplotlib.lines.Line2D at 0x1b430770310>,
#  <matplotlib.lines.Line2D at 0x1b430770690>,
#  <matplotlib.lines.Line2D at 0x1b430780cd0>,
#  <matplotlib.lines.Line2D at 0x1b430652b90>,
#  <matplotlib.lines.Line2D at 0x1b430771310>,
#  <matplotlib.lines.Line2D at 0x1b430771990>,
#  <matplotlib.lines.Line2D at 0x1b42ed82710>,
#  <matplotlib.lines.Line2D at 0x1b430639b50>,
#  <matplotlib.lines.Line2D at 0x1b430652550>,
#  <matplotlib.lines.Line2D at 0x1b430611310>,
#  <matplotlib.lines.Line2D at 0x1b430772c90>,
#  <matplotlib.lines.Line2D at 0x1b430638a50>,
#  <matplotlib.lines.Line2D at 0x1b430773550>,
#  <matplotlib.lines.Line2D at 0x1b43063bad0>,
#  <matplotlib.lines.Line2D at 0x1b43061bed0>,
#  <matplotlib.lines.Line2D at 0x1b430820250>,
#  <matplotlib.lines.Line2D at 0x1b4306107d0>,
#  <matplotlib.lines.Line2D at 0x1b430820ad0>,
#  <matplotlib.lines.Line2D at 0x1b430820f50>,
#  <matplotlib.lines.Line2D at 0x1b4307714d0>,
#  <matplotlib.lines.Line2D at 0x1b430821990>,
#  <matplotlib.lines.Line2D at 0x1b430821c10>]

# %%
cwd = os.getcwd()
Y_path = os.path.join(cwd, "folds", "test_fold_21_Y.txt")
np.savetxt(Y_path, Y)

# %%
X_path = os.path.join(cwd, "folds", "test_fold_21_X.pickle")
with open(X_path, 'wb') as f:
    pickle.dump([X], f)

# %%
Z_path = os.path.join(cwd, "folds", "test_fold_21_Z.txt")
with open(Z_path, 'wb') as f:
    pickle.dump(Z, f)

# %%
# cwd = os.getcwd()
# X_path = os.path.join(cwd, "folds", "%s_fold_%s_X.pickle" % ('x2y3', 1)) #os.path.join(cwd, "folds", "x2y3_fold_1_X.pickle")
# with open(X_path, 'rb') as f:
#     X_test = pickle.load(f)
